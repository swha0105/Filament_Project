# %%
import numpy as np
import sys 
import os
import matplotlib.pyplot as plt
os.chdir('/storage/filament/codes/')
#from utils import *
import copy 
import cv2

# %%
box_list = ['02']
#subbox_num = ''

subbox_list = ['1','2','3','4','5','6','7','8']

distance = '40Mpc'

if distance == '30Mpc':
    box_size = 37
if distance == '40Mpc':
    box_size = 50
for box_num in box_list:
    for subbox_num in subbox_list:
        data_path = '/storage/filament/data/box'+box_num +'/'
        dens_result_path = '/storage/filament/result/cluster_3d/' + distance + '/density_log_plot/box' + box_num + '/subbox0' +subbox_num + '/'
        dens_smooth_path_5 =  '/storage/filament/result/cluster_3d/' + distance + '/density_smoothing_plot_5_v2/box' + box_num + '/subbox0' +subbox_num + '/'
        data_type = ['a','f','g']
        # a = density
        # f = temperature
        # g = xray   

        dens = np.zeros(256**3,dtype='float64')
        dens = np.genfromtxt(data_path + '256den18' + data_type[0] + '+1024+' + subbox_num,dtype='float64')
        dens_mat = dens.reshape([256,256,256])

        temp = np.zeros(256**3,dtype='float64')
        temp = np.genfromtxt(data_path + '256den18' + data_type[1] + '+1024+' + subbox_num,dtype='float64')
        temp_mat = temp.reshape([256,256,256])

        index_path = '/storage/filament/data/box'+box_num +'+Cinfo/'
        index = np.genfromtxt(index_path + 'box' + box_num + '+xlum+' + subbox_num+'.dat',dtype='uint8')

        x_index = index[:,3]-1
        y_index = index[:,2]-1
        z_index = index[:,1]-1

        coords = np.array(list(zip(x_index,y_index,z_index)))
        coords = np.array(sorted(coords, key=lambda x:x[2] ))

        box_list =[]
        temp_point = np.zeros([box_size*2,box_size*2,box_size*2],dtype='float64')
        dens_3d = np.zeros([box_size*2,box_size*2,box_size*2],dtype='float64')
        smooth_dens = np.zeros([box_size*2,box_size*2,box_size*2],dtype='float64')

        cluster_peak_thres = 2*1.16*10**7

        min_thres = 0.5
        max_thres = 0.7
        min_thres_2 = 1.0
        max_thres_2 = 1.5



        num=0

        print('box_num ', box_num, 'subbox_num ',subbox_num, 'density')

        for n,(ix,iy,iz) in enumerate(coords):
            if (ix < box_size or ix>256-box_size or iy < box_size or iy > 256-box_size or iz <box_size or iz >256-box_size):
                continue
            else:
                if temp_mat[ix,iy,iz] >= cluster_peak_thres:
                    print('box_num ', box_num, 'subbox_num ',subbox_num, 'density',ix,iy,iz)
                    dens_3d[:,:,:] = dens_mat[-box_size+ix:box_size+ix,-box_size+iy:box_size+iy,-box_size+iz:box_size+iz]


                    smooth_dens = smooting_3d(dens_3d,4)
                    smooth_dens = smooth_dens[2:100-2,2:100-2,2:100-2]

                    if not os.path.isdir(dens_smooth_path_5 + str(num) + '/binary_data/'):
                         os.makedirs(dens_smooth_path_5 + str(num) + '/binary_data/')
                    #os.chdir(dens_smooth_path_5 + str(num) + '/')            
                    #os.makedirs(dens_smooth_path_5 + 'data/')
                    os.chdir(dens_smooth_path_5 + str(num) + '/binary_data/')  

                    np.save('smooth_data',smooth_dens)
        #             for nn in range(2*box_size-4):
        #                 plt.figure(figsize=[30,30])
        #                 plt.imsave(str(nn) +'.png',np.log10(smooth_dens[:,:,nn]),vmin=-1,vmax=1,cmap='gray',dpi=300,format='png')



                    num = num+1
# Out:
# box_num  02 subbox_num  1 density
# box_num  02 subbox_num  1 density 105 134 64
# box_num  02 subbox_num  1 density 130 150 80
# box_num  02 subbox_num  1 density 91 56 189
# box_num  02 subbox_num  2 density
# box_num  02 subbox_num  2 density 129 162 170
# box_num  02 subbox_num  3 density
# box_num  02 subbox_num  3 density 131 162 105
# box_num  02 subbox_num  3 density 128 142 119
# box_num  02 subbox_num  4 density
# box_num  02 subbox_num  4 density 194 160 56
# box_num  02 subbox_num  4 density 161 79 58
# box_num  02 subbox_num  5 density
# box_num  02 subbox_num  5 density 85 167 91
# box_num  02 subbox_num  5 density 137 184 187
# box_num  02 subbox_num  6 density
# box_num  02 subbox_num  6 density 77 177 97
# box_num  02 subbox_num  6 density 89 190 105
# box_num  02 subbox_num  6 density 131 197 138
# box_num  02 subbox_num  7 density
# box_num  02 subbox_num  7 density 65 112 194
# box_num  02 subbox_num  7 density 87 101 204
# box_num  02 subbox_num  8 density
# box_num  02 subbox_num  8 density 163 59 87

# %%
box_list = ['01','02']


distance = '40Mpc'

if distance == '30Mpc':
    box_size = 37
if distance == '40Mpc':
    box_size = 50
for box_num in box_list:
    data_path = '/storage/filament/data/box'+box_num +'_add' + '/box' + box_num +'_norm/'
    data_list = os.listdir(data_path)
    
    for _,data_name in enumerate(data_list):
        dens = np.zeros(101**3,dtype='float64')
        dens = np.genfromtxt(data_path + data_name,dtype='float64')
        dens_mat = dens.reshape([101,101,101])        
        dens_smooth_path_5 =  '/storage/filament/result/cluster_3d/' + distance + '/density_smoothing_plot_5_v2/box' + box_num + '_add/' + data_name[:-4] +'/'
    
        smooth_dens = np.zeros([101,101,101],dtype='float64')

        

        print(data_name)

        smooth_dens = smooting_3d(dens_mat,4)
        smooth_dens = smooth_dens[2:100-2,2:100-2,2:100-2]

        if not os.path.isdir(dens_smooth_path_5  + '/binary_data/'):
             os.makedirs(dens_smooth_path_5  + '/binary_data/')
        os.chdir(dens_smooth_path_5  + '/binary_data/')  

        np.save('smooth_data',smooth_dens)
# Out:
# box01sub08C01.dat
# box01sub06C07.dat
# box01sub05C06.dat
# box01sub05C03.dat
# box01sub07C07.dat
# box01sub01C05.dat
# box01sub07C09.dat
# box01sub02C03.dat
# box01sub01C03.dat
# box01sub06C03.dat
# box01sub03C03.dat
# box01sub05C02.dat
# box01sub05C04.dat
# box01sub08C07.dat
# box01sub02C09.dat
# box01sub08C05.dat
# box01sub07C05.dat
# box01sub08C02.dat
# box01sub02C12.dat
# box01sub07C04.dat
# box01sub02C08.dat
# box01sub04C02.dat
# box01sub02C01.dat
# box01sub07C01.dat
# box01sub08C08.dat
# box01sub03C01.dat
# box01sub07C03.dat
# box01sub05C07.dat
# box01sub05C01.dat
# box01sub06C08.dat
# box01sub02C05.dat
# box01sub05C05.dat
# box01sub02C04.dat
# box01sub01C06.dat
# box01sub06C04.dat
# box01sub06C06.dat
# box01sub02C06.dat
# box01sub01C02.dat
# box01sub03C06.dat
# box01sub06C05.dat
# box01sub02C11.dat
# box01sub01C01.dat
# box01sub01C04.dat
# box01sub02C02.dat
# box01sub03C02.dat
# box01sub03C04.dat
# box01sub06C01.dat
# box01sub04C01.dat
# box01sub07C06.dat
# box01sub02C07.dat
# box01sub08C09.dat
# box01sub02C10.dat
# box01sub07C02.dat
# box01sub03C05.dat
# box01sub08C03.dat
# box01sub08C06.dat
# box01sub07C08.dat
# box01sub06C02.dat
# box01sub08C04.dat
# box02sub01C13.dat
# box02sub08C04.dat
# box02sub03C03.dat
# box02sub04C06.dat
# box02sub05C05.dat
# box02sub01C15.dat
# box02sub05C11.dat
# box02sub03C07.dat
# box02sub01C11.dat
# box02sub01C05.dat
# box02sub05C13.dat
# box02sub05C12.dat
# box02sub08C06.dat
# box02sub01C10.dat
# box02sub07C05.dat
# box02sub02C03.dat
# box02sub06C01.dat
# box02sub03C04.dat
# box02sub03C08.dat
# box02sub05C10.dat
# box02sub07C02.dat
# box02sub08C02.dat
# box02sub05C15.dat
# box02sub06C08.dat
# box02sub03C02.dat
# box02sub03C06.dat
# box02sub05C09.dat
# box02sub05C06.dat
# box02sub01C01.dat
# box02sub06C07.dat
# box02sub01C09.dat
# box02sub03C09.dat
# box02sub03C10.dat
# box02sub05C01.dat
# box02sub02C04.dat
# box02sub06C03.dat
# box02sub07C03.dat
# box02sub05C03.dat
# box02sub01C12.dat
# box02sub02C01.dat
# box02sub01C02.dat
# box02sub01C06.dat
# box02sub06C04.dat
# box02sub08C01.dat
# box02sub05C04.dat
# box02sub04C05.dat
# box02sub04C03.dat
# box02sub02C02.dat
# box02sub04C01.dat
# box02sub08C05.dat
# box02sub04C02.dat
# box02sub03C05.dat
# box02sub07C04.dat
# box02sub01C03.dat
# box02sub04C04.dat
# box02sub06C05.dat
# box02sub01C08.dat
# box02sub01C14.dat
# box02sub03C01.dat
# box02sub06C02.dat
# box02sub01C16.dat
# box02sub05C14.dat
# box02sub07C01.dat
# box02sub05C08.dat
# box02sub05C02.dat
# box02sub06C06.dat
# box02sub05C07.dat
# box02sub08C03.dat
# box02sub01C04.dat
# box02sub01C07.dat

# %%
def smooting_3d(array,smooth_size):
    array_len = array.shape[0]
    half_smooth_size = int(smooth_size/2)
    #smooth_array = np.zeros([array_len-smooth_size,array_len-smooth_size,array_len-smooth_size])
    smooth_array = np.zeros([array_len,array_len,array_len])
    for i in range(half_smooth_size,array_len-half_smooth_size):
        for j in range(half_smooth_size,array_len-half_smooth_size):
            for k in range(half_smooth_size,array_len-half_smooth_size):
                

                #smooth_array[i,j,k] = np.mean(array[i-half_smooth_size:i+half_smooth_size+1,j-half_smooth_size:j+half_smooth_size+1,k-half_smooth_size:k+half_smooth_size+1])
                smooth_array[i,j,k] = (1/(smooth_size+1)**3)*np.sum(array[i-half_smooth_size:i+half_smooth_size+1,j-half_smooth_size:j+half_smooth_size+1,k-half_smooth_size:k+half_smooth_size+1])    
    
    #print("b",smooth_array.shape)
    return smooth_array

# %%
for _,name in enumerate(os.listdir('/storage/filament/data/box01_add/box01_norm')):
    print(name[:-4])
# Out:
# box01sub08C01
# box01sub06C07
# box01sub05C06
# box01sub05C03
# box01sub07C07
# box01sub01C05
# box01sub07C09
# box01sub02C03
# box01sub01C03
# box01sub06C03
# box01sub03C03
# box01sub05C02
# box01sub05C04
# box01sub08C07
# box01sub02C09
# box01sub08C05
# box01sub07C05
# box01sub08C02
# box01sub02C12
# box01sub07C04
# box01sub02C08
# box01sub04C02
# box01sub02C01
# box01sub07C01
# box01sub08C08
# box01sub03C01
# box01sub07C03
# box01sub05C07
# box01sub05C01
# box01sub06C08
# box01sub02C05
# box01sub05C05
# box01sub02C04
# box01sub01C06
# box01sub06C04
# box01sub06C06
# box01sub02C06
# box01sub01C02
# box01sub03C06
# box01sub06C05
# box01sub02C11
# box01sub01C01
# box01sub01C04
# box01sub02C02
# box01sub03C02
# box01sub03C04
# box01sub06C01
# box01sub04C01
# box01sub07C06
# box01sub02C07
# box01sub08C09
# box01sub02C10
# box01sub07C02
# box01sub03C05
# box01sub08C03
# box01sub08C06
# box01sub07C08
# box01sub06C02
# box01sub08C04
